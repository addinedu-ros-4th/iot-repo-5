# %%
import socket
server_port = 8090
max_users = 5 #maximum number of queued connections

# %%
server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
server_socket.bind(("0.0.0.0", server_port))
server_socket.listen(max_users)

# %%
print ("Waiting for client on port ",server_port)
# Out:
# Waiting for client on port  8090

# %%
def comm():
	count = 0
	
	while True:
		client_socket, client_address = server_socket.accept()
		print ("connection from ", client_address)
		while True:
			data = client_socket.recv(1024)
			if not data:
				break
			
			decoded = data.decode()
			print(count, 'received :', decoded)
			# send_data = "[Hi, I'm TH KIM. I got this Message.] => " + decoded
			send_data = '5'
			encoded_send_data = send_data.encode('utf-8')
			sent = client_socket.send(encoded_send_data)
			
			if sent == 0:
				print("socket connection broken")
			print(sent)
		print("Disconnected")
		client_socket.close()
		count = count+1

# %%
comm()
# Out:
# connection from  ('192.168.0.29', 47382)
# 0 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 28904)
# 1 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 45048)
# 2 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 5497)
# 3 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 41440)
# 4 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 17447)
# 5 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 23344)
# 6 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 1720)
# 7 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 46361)
# 8 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 40695)
# 9 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 6703)
# 10 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 49246)
# 11 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 29534)
# 12 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 4668)
# 13 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 13213)
# 14 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 31103)
# 15 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 26515)
# 16 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 12990)
# 17 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 32331)
# 18 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 35711)
# 19 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 45305)
# 20 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 27271)
# 21 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 1747)
# 22 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 20295)
# 23 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 2043)
# 24 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 27593)
# 25 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 24227)
# 26 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 37141)
# 27 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 36583)
# 28 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 20531)
# 29 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 27328)
# 30 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 47298)
# 31 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 10652)
# 32 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 30979)
# 33 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 28449)
# 34 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 20035)
# 35 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 32036)
# 36 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 13242)
# 37 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 38757)
# 38 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 41638)
# 39 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 26058)
# 40 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 22185)
# 41 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 42098)
# 42 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 31061)
# 43 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 24843)
# 44 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 20079)
# 45 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 48637)
# 46 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 21038)
# 47 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 13338)
# 48 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 22183)
# 49 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 43770)
# 50 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 27467)
# 51 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 45781)
# 52 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 13363)
# 53 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 1081)
# 54 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 37376)
# 55 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 49452)
# 56 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 8788)
# 57 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 47055)
# 58 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 43314)
# 59 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 4245)
# 60 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 40930)
# 61 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 44144)
# 62 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 20203)
# 63 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 11486)
# 64 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 1768)
# 65 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 15561)
# 66 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 3776)
# 67 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 31612)
# 68 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 19777)
# 69 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 9738)
# 70 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 11665)
# 71 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 9363)
# 72 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 7000)
# 73 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 9254)
# 74 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 33965)
# 75 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 9590)
# 76 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 23835)
# 77 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 31219)
# 78 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 10760)
# 79 received : Hello, this is client!
# 1
# Disconnected
# connection from  ('192.168.0.29', 27577)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 comm()
#
# Cell In[4], line 8, in comm()
#       6 print ("connection from ", client_address)
#       7 while True:
# ----> 8 	data = client_socket.recv(1024)
#       9 	if not data:
#      10 		break
#
# KeyboardInterrupt:

# %%
server_socket.close()
